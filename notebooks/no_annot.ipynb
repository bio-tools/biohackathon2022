# %%
from rdflib import ConjunctiveGraph
from SPARQLWrapper import SPARQLWrapper, JSON
import matplotlib.pyplot as plt
from matplotlib_venn import venn2
import numpy as np


import pandas as pd

def remoteQuery(query, endpoint):
    endpoint.setQuery(query)
    try:
        result = endpoint.queryAndConvert()
        pd.set_option("display.max_rows",None,"display.max_colwidth",6000,"display.width",6000,)
        df = pd.DataFrame(result['results']['bindings'])
        df = df.applymap(lambda x: x['value'])
        return df
        #return (result['results']['bindings'])
    except Exception as e:
        print(e)
ep_biotools = SPARQLWrapper("http://localhost:7200/repositories/Project25")
ep_biotools.setReturnFormat(JSON)

# %% [markdown]
# ## Checks for tools without any EDAM annotation

# %%
query=""" 
PREFIX edam:<http://edamontology.org/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX bsc: <http://bioschemas.org/>
PREFIX bsct: <http://bioschemas.org/types/>
PREFIX sc: <http://schema.org/>



SELECT DISTINCT ?tool  WHERE {

# ?tool rdf:type sc:SoftwareApplication ;
 FILTER NOT EXISTS {  
   # ?tool sc:applicationSubCategory ?topic.
   }
 FILTER NOT EXISTS {  
   # ?tool    sc:featureList ?operation  .
   }
}
"""

# %% [markdown]
# To analyse bio.tools a Bioschemas dump have been generated using json file for each tool, generated up to the beginning of 2022. Here a lot of tools reported as having no edam annotation have been updated in the bio.tools repository

# %%
results=remoteQuery(query=query, endpoint=ep_biotools)
print(int(len(results)))
display(results)
# Out:
# 297
#                                                                                             tool
# 0                                                             https://bio.tools/1928_diagnostics
# 1                                                  https://bio.tools/2dar2darma-param-estimation
# 2                                               https://bio.tools/3d-kinematics-inverse-dynamics
# 3                                                                 https://bio.tools/AAI-profiler
# 4                                                                         https://bio.tools/ACSN
# 5                                                                         https://bio.tools/AGAT
# 6                                                                    https://bio.tools/ALIENNESS
# 7                                                                   https://bio.tools/AgroPortal
# 8                                                                 https://bio.tools/AntiHIV-Pred
# 9                                                                https://bio.tools/CLIP-Explorer
# 10                                                          https://bio.tools/CWL_VM_environment
# 11                                                                     https://bio.tools/ChemEnv
# 12                                                                     https://bio.tools/CmPIweb
# 13                                                                      https://bio.tools/Dwarna
# 14                                                                     https://bio.tools/Eoulsan
# 15                                                             https://bio.tools/EvidenceModeler
# 16                                                                       https://bio.tools/GADMA
# 17                                                                   https://bio.tools/GUESSmyLT
# 18                                                                 https://bio.tools/GeneMarkS-T
# 19                                                                     https://bio.tools/Genotom
# 20                                                                  https://bio.tools/HIV-ASSIST
# 21                                                                      https://bio.tools/Holmes
# 22                                                                   https://bio.tools/KisSplice
# 23                                                                    https://bio.tools/Laniakea
# 24                                                                      https://bio.tools/MCScan
# 25                             https://bio.tools/MESSAR_MEtabolite_SubStructure_Auto-Recommender
# 26                                https://bio.tools/Metagenomic_read_binning_using_sparse_coding
# 27                                          https://bio.tools/Multi-omics_Visualization_Platform
# 28                                        https://bio.tools/Multiple_Myeloma_survival_prediction
# 29                                                                https://bio.tools/NCBI-protein
# 30                                                                         https://bio.tools/NaS
# 31                                                                    https://bio.tools/OrthoMCL
# 32                                                                        https://bio.tools/PASA
# 33                                                             https://bio.tools/PASTEClassifier
# 34                                                                      https://bio.tools/PGxLOD
# 35                                                                 https://bio.tools/PanGeneHome
# 36                                                                    https://bio.tools/Paraload
# 37                                                                https://bio.tools/Pasteur_MLST
# 38                                                                https://bio.tools/Pred-BVP-Unb
# 39                                                                     https://bio.tools/PyDFN3D
# 40                                                              https://bio.tools/RealityConvert
# 41                                                                 https://bio.tools/RepeatScout
# 42                                                                 https://bio.tools/SMARTdenovo
# 43                                                                     https://bio.tools/SPROUTS
# 44                                                                     https://bio.tools/ScanITD
# 45                                                                     https://bio.tools/SpCLUST
# 46                                                                  https://bio.tools/TE-Tracker
# 47                                                                   https://bio.tools/Telescope
# 48                                                                   https://bio.tools/ToulligQC
# 49                                                                https://bio.tools/TransDecoder
# 50                                                           https://bio.tools/Tutorial_MD_Setup
# 51                                                                     https://bio.tools/UPCLASS
# 52                                                                     https://bio.tools/VEnCode
# 53                                                            https://bio.tools/VariantValidator
# 54                                                https://bio.tools/Victor-clustering-comparison
# 55                                                      https://bio.tools/Zebrafish_neuroanatomy
# 56                                                              https://bio.tools/adapterremoval
# 57                                                                    https://bio.tools/amr-meta
# 58                                             https://bio.tools/ants_marking_and_analysis_tools
# 59                                                                  https://bio.tools/arena3dweb
# 60                                    https://bio.tools/arthropoda_assembly_assessment_catalogue
# 61                                        https://bio.tools/assignment_of_dna_and_rna_conformers
# 62                                                      https://bio.tools/auc-comparison-p-value
# 63                                                                     https://bio.tools/aucpred
# 64                                                                https://bio.tools/autoclassweb
# 65                    https://bio.tools/bandar_togel_online_singapore_4d_deposit_dana_terpercaya
# 66                          https://bio.tools/bandar_togel_online_singapore_4d_sgp_49_terpercaya
# 67                                 https://bio.tools/bandar_togel_online_singapore_4d_terpercaya
# 68                           https://bio.tools/bandar_togel_online_singapore_pools_4d_terpercaya
# 69                                                                  https://bio.tools/basenumber
# 70                                                                     https://bio.tools/bedsect
# 71                                                               https://bio.tools/bedtogenepred
# 72                                                          https://bio.tools/bigwas_qc_pipeline
# 73                                                              https://bio.tools/binary-volumes
# 74                                                       https://bio.tools/bio_contrast_subgraph
# 75                                                                  https://bio.tools/biofouling
# 76                                                                      https://bio.tools/biolib
# 77                                                                      https://bio.tools/biolqm
# 78                                                                https://bio.tools/biovalidator
# 79   https://bio.tools/bit-table-biclustering-closed-itemset-mining-high-dimensional-binary-data
# 80                                                        https://bio.tools/blind_docking_server
# 81                           https://bio.tools/blood-glucose-regulation-type-i-diabetic-simulink
# 82                                                                 https://bio.tools/bnreduction
# 83                                                                     https://bio.tools/bonesis
# 84                                                                  https://bio.tools/booleannet
# 85                                                                     https://bio.tools/boolnet
# 86                                                                       https://bio.tools/boost
# 87                                                          https://bio.tools/breast-body-fusion
# 88                                                                  https://bio.tools/canprosite
# 89                                                                      https://bio.tools/caosdb
# 90                                                                  https://bio.tools/casualpath
# 91                                                              https://bio.tools/cellcollective
# 92                                                                https://bio.tools/cellmodeller
# 93                                                                     https://bio.tools/cellsys
# 94                                                                   https://bio.tools/chemchain
# 95                                                            https://bio.tools/chemical_checker
# 96                                                                    https://bio.tools/chm-eval
# 97                                                             https://bio.tools/chunkchromosome
# 98                                                                  https://bio.tools/clintrajan
# 99                                                                       https://bio.tools/cojac
# 100                                                                   https://bio.tools/comparem
# 101                                                 https://bio.tools/confidence-intervals-auroc
# 102                                                                     https://bio.tools/cordax
# 103                                                           https://bio.tools/corrdrugtumormsi
# 104                                                               https://bio.tools/covalentdock
# 105                                                                   https://bio.tools/covtools
# 106                                                               https://bio.tools/cwl_training
# 107                                                                https://bio.tools/d-structman
# 108                                                                   https://bio.tools/dadaist2
# 109                                                                       https://bio.tools/dapt
# 110                                                     https://bio.tools/dark_proteome_database
# 111                                                                       https://bio.tools/deap
# 112                                                             https://bio.tools/decomppipeline
# 113                                  https://bio.tools/deep_transfer_graph_convolutional_network
# 114                                                                https://bio.tools/deepdrpbind
# 115                                                                     https://bio.tools/deepvp
# 116                                                                    https://bio.tools/dflpred
# 117                                                                  https://bio.tools/disopred3
# 118                                                                https://bio.tools/dispredict2
# 119                                                                https://bio.tools/dispredict3
# 120                                                                     https://bio.tools/dodona
# 121                                                               https://bio.tools/domprint_gps
# 122                                                                    https://bio.tools/drderma
# 123                                                                    https://bio.tools/drpbind
# 124                                                                    https://bio.tools/dsysmap
# 125                                                                        https://bio.tools/ecj
# 126                                               https://bio.tools/effective_brain_connectivity
# 127                                                        https://bio.tools/eido-python-package
# 128                                                                      https://bio.tools/emews
# 129                                                                   https://bio.tools/emgonoff
# 130                                                                  https://bio.tools/ewastools
# 131                                                                    https://bio.tools/extaxsi
# 132                                                                  https://bio.tools/factorviz
# 133                                             https://bio.tools/fair4health_data_curation_tool
# 134                                                                   https://bio.tools/fast-auc
# 135                                                             https://bio.tools/fast-perfcurve
# 136                                                                   https://bio.tools/fastcore
# 137                                                                 https://bio.tools/fatotwobit
# 138                                                                    https://bio.tools/favicov
# 139                                                                      https://bio.tools/fgbio
# 140                                                                   https://bio.tools/filtlong
# 141                                                           https://bio.tools/flame-enrichment
# 142                                                                https://bio.tools/flame_gpu_2
# 143                                                                 https://bio.tools/foldunfold
# 144                                                                  https://bio.tools/fpga_perm
# 145                                                               https://bio.tools/ft-comar2298
# 146                                      https://bio.tools/gacorbang_88_link_alternatif_joker138
# 147                                                        https://bio.tools/gbrowse_giant_virus
# 148                                                                    https://bio.tools/gdc-api
# 149                                                                 https://bio.tools/gdc-client
# 150                                                                      https://bio.tools/geco3
# 151                                                                       https://bio.tools/gemb
# 152                                                             https://bio.tools/gene_structure
# 153                                                                https://bio.tools/genie-codec
# 154                                               https://bio.tools/genmesh-avs-matlab-converter
# 155                                                                   https://bio.tools/genomepy
# 156                                                                 https://bio.tools/gethgvbase
# 157                                                            https://bio.tools/godel-numbering
# 158                                                                  https://bio.tools/graditude
# 159                                                                        https://bio.tools/gsl
# 160                                                             https://bio.tools/herbert_prater
# 161                                                            https://bio.tools/hifiadapterfilt
# 162                          https://bio.tools/hungarian-algorithm-linear-sum-assignment-problem
# 163                                                         https://bio.tools/ibd_benchmark_tool
# 164                                                                    https://bio.tools/igidiva
# 165                                                                   https://bio.tools/iirtplay
# 166                                                                  https://bio.tools/influx_si
# 167                                                              https://bio.tools/interactome3d
# 168                                                                 https://bio.tools/interleafq
# 169                                                                    https://bio.tools/intside
# 170                                                                   https://bio.tools/ipa_hifi
# 171                                                                 https://bio.tools/ipath_IMIM
# 172                                                                   https://bio.tools/ipk-cats
# 173                                                                    https://bio.tools/irtbemm
# 174                                                                 https://bio.tools/isunstruct
# 175                                                                   https://bio.tools/itsonewb
# 176                                                         https://bio.tools/jellyfish_gfp_mrna
# 177                                                               https://bio.tools/ketoadvanced
# 178                                                               https://bio.tools/kmeranalyzer
# 179                                                                       https://bio.tools/kpnn
# 180                                                               https://bio.tools/label3dmaize
# 181                                                                   https://bio.tools/learnMSA
# 182                                                                    https://bio.tools/liferay
# 183                                   https://bio.tools/light_attention_subcellular_localization
# 184                                                                https://bio.tools/like_a_diva
# 185                                                                https://bio.tools/lineagespot
# 186                                                                     https://bio.tools/lofreq
# 187                                                              https://bio.tools/ltr_retriever
# 188                                                         https://bio.tools/maestro_standalone
# 189                                                                     https://bio.tools/matlab
# 190                                                                   https://bio.tools/mego_pay
# 191                                                                    https://bio.tools/memblob
# 192                                                                     https://bio.tools/memote
# 193                                                               https://bio.tools/metagenemark
# 194                                                                 https://bio.tools/metaprokka
# 195                                                                  https://bio.tools/metaseqr2
# 196                                                                   https://bio.tools/mineprot
# 197                                                                     https://bio.tools/mirkit
# 198                                                                       https://bio.tools/mofi
# 199                                                                      https://bio.tools/molup
# 200                                                                   https://bio.tools/mongoose
# 201                                                                 https://bio.tools/nanogalaxy
# 202                                                                      https://bio.tools/navip
# 203                                                                      https://bio.tools/nccmp
# 204                                                                        https://bio.tools/nco
# 205                                                                     https://bio.tools/netcdf
# 206                                                                       https://bio.tools/npsv
# 207                                                                      https://bio.tools/nucls
# 208                                                                      https://bio.tools/odefy
# 209                                                                  https://bio.tools/odysseyoa
# 210                                                      https://bio.tools/oncogenomiclandscapes
# 211                                                                   https://bio.tools/onthefly
# 212                                                                https://bio.tools/open-cravat
# 213                                                                   https://bio.tools/openmole
# 214                                                                https://bio.tools/optimusqual
# 215                                                                   https://bio.tools/optitype
# 216                                                                     https://bio.tools/optpbn
# 217                                                                   https://bio.tools/panoptes
# 218                                                                 https://bio.tools/panoromics
# 219                                                                   https://bio.tools/parallel
# 220                                                                https://bio.tools/parliament2
# 221                                                                https://bio.tools/partition_r
# 222                                                                      https://bio.tools/pbmm2
# 223                                                                   https://bio.tools/pdbinder
# 224                                                       https://bio.tools/peppy-python-package
# 225                                                             https://bio.tools/pepr-R-package
# 226                                                                https://bio.tools/physicell-x
# 227                                              https://bio.tools/picard_addorreplacereadgroups
# 228                                                   https://bio.tools/picard_bedtointervallist
# 229                                      https://bio.tools/picard_collectalignmentsummarymetrics
# 230                                                    https://bio.tools/picard_collecthsmetrics
# 231                                                                https://bio.tools/pipprofiler
# 232                                                           https://bio.tools/plant_ptm_viewer
# 233                                                                     https://bio.tools/pm4ngs
# 234                                                            https://bio.tools/predictsnp-onco
# 235                                                                https://bio.tools/predisorder
# 236                                                                 https://bio.tools/primerclip
# 237                                              https://bio.tools/protein_dipole_moments_server
# 238                                                                      https://bio.tools/pyhca
# 239                                                                 https://bio.tools/qcGenomics
# 240                                                                    https://bio.tools/qiber3d
# 241                                                                     https://bio.tools/r-gada
# 242                                                                   https://bio.tools/randcorr
# 243                                                                     https://bio.tools/rasusa
# 244                                                                    https://bio.tools/razers3
# 245                                                                    https://bio.tools/refinem
# 246                                                                   https://bio.tools/reframed
# 247                                                                     https://bio.tools/repair
# 248                                                                      https://bio.tools/rexdb
# 249                                                                       https://bio.tools/rfsc
# 250                                                                        https://bio.tools/s2d
# 251                                                                 https://bio.tools/salmobase2
# 252                                                https://bio.tools/sars-cov-2-network-analysis
# 253                                                                      https://bio.tools/sciga
# 254                                                                     https://bio.tools/scomap
# 255                                                                     https://bio.tools/scrnax
# 256                                                                   https://bio.tools/scshapes
# 257                                                                      https://bio.tools/scthi
# 258                                                                   https://bio.tools/sdypools
# 259                                                                     https://bio.tools/seth_1
# 260                                                                     https://bio.tools/seurat
# 261                                                                   https://bio.tools/sgppools
# 262                                              https://bio.tools/sierpinski-triangle-recursion
# 263                                                      https://bio.tools/simbiology-tmdd-model
# 264                                                               https://bio.tools/simple-blast
# 265                                                           https://bio.tools/simpledsfviewer1
# 266                                                           https://bio.tools/situs_poker_2022
# 267                                                                     https://bio.tools/skempi
# 268                                                                    https://bio.tools/smashpp
# 269                                                                     https://bio.tools/snpkit
# 270                                                              https://bio.tools/spot-disorder
# 271                                                       https://bio.tools/spot-disorder-single
# 272                                                                 https://bio.tools/start-asap
# 273                                                                   https://bio.tools/sub-spia
# 274                                                                      https://bio.tools/tabix
# 275                                                               https://bio.tools/taguchiarray
# 276                                                                     https://bio.tools/tarean
# 277                                                                  https://bio.tools/teslatoto
# 278                                                                     https://bio.tools/tiedie
# 279                                                                    https://bio.tools/timothy
# 280                      https://bio.tools/tool_recommender_system_in_galaxy_using_deep_learning
# 281                         https://bio.tools/toolkits-monte-carlo-dose-simulation-visualization
# 282                                                                 https://bio.tools/tourmaline
# 283                                                                        https://bio.tools/tps
# 284                                                                 https://bio.tools/tracespipe
# 285                                                                 https://bio.tools/twobitinfo
# 286                                                                   https://bio.tools/uROCcomp
# 287                                                                       https://bio.tools/umic
# 288                                                               https://bio.tools/variantspark
# 289                                                                      https://bio.tools/vfuzz
# 290                                                                      https://bio.tools/visit
# 291                                                                       https://bio.tools/vsl2
# 292                                                              https://bio.tools/vulcan_mapper
# 293                                                                   https://bio.tools/watchdog
# 294                                                                      https://bio.tools/wgsim
# 295                                                               https://bio.tools/whatismygene
# 296                                                                      https://bio.tools/yalla
