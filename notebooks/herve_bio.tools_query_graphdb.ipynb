# %% [markdown]
# ## Set up

# %%
from rdflib import ConjunctiveGraph
from SPARQLWrapper import SPARQLWrapper, JSON
import matplotlib.pyplot as plt
from matplotlib_venn import venn2
import numpy as np


import pandas as pd

def remoteQuery(query, endpoint):
    endpoint.setQuery(query)
    try:
        result = endpoint.queryAndConvert()
        pd.set_option("display.max_rows",None,"display.max_colwidth",6000,"display.width",6000,)
        df = pd.DataFrame(result['results']['bindings'])
        df = df.applymap(lambda x: x['value'])
        return df
        #return (result['results']['bindings'])
    except Exception as e:
        print(e)

# %%
ep_biotools = SPARQLWrapper("http://localhost:7200/repositories/Project25")
ep_biotools.setReturnFormat(JSON)

# %% [markdown]
# ## How many EDAM data are there in EDAM?

# %%
q= """
PREFIX edam:<http://edamontology.org/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>

PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX bsc: <http://bioschemas.org/>
PREFIX bsct: <http://bioschemas.org/types/>

PREFIX sc: <http://schema.org/>
SELECT (COUNT(DISTINCT ?data) as ?count) WHERE {
    # ?data rdfs:subClassOf <http://edamontology.org/data_0006>
}
"""
print(f"Total number of EDAM data: {len(remoteQuery(query=q, endpoint=ep_biotools))}")
remoteQuery(query=q, endpoint=ep_biotools)
# Out:
# Total number of EDAM data: 1
#   count
# 0   947

# %% [markdown]
# ## How many EDAM data are used to annotate bio.tools?

# %%
q= """
PREFIX edam:<http://edamontology.org/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>

PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX bsc: <http://bioschemas.org/>
PREFIX bsct: <http://bioschemas.org/types/>

PREFIX sc: <http://schema.org/>
SELECT (COUNT(DISTINCT ?data) as ?count) WHERE {
    {
# ?biotools_id rdf:type <http://schema.org/SoftwareApplication> ;
   bsc:input [sc:additionalType ?data].        
    } UNION {
# ?biotools_id rdf:type <http://schema.org/SoftwareApplication> ;
   bsc:output [sc:additionalType ?data].        
    }
}
"""
print(f"Total number of EDAM data used to annotate bio.tools: {len(remoteQuery(query=q, endpoint=ep_biotools))}")
remoteQuery(query=q, endpoint=ep_biotools)
# Out:
# Total number of EDAM data used to annotate bio.tools: 1
#   count
# 0   559

# %% [markdown]
# ## How many bio.tools entries are annotated with EDAM data?

# %%
q= """
PREFIX edam:<http://edamontology.org/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>

PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX bsc: <http://bioschemas.org/>
PREFIX bsct: <http://bioschemas.org/types/>

PREFIX sc: <http://schema.org/>
SELECT (COUNT(DISTINCT ?biotools_id) as ?count) WHERE {
    {
# ?biotools_id rdf:type <http://schema.org/SoftwareApplication> ;
   bsc:input [sc:additionalType ?data].        
    } UNION {
# ?biotools_id rdf:type <http://schema.org/SoftwareApplication> ;
   bsc:output [sc:additionalType ?data].        
    }
}
"""
print(f"Total number of bio.tools entries used to annotate EDAM data: {len(remoteQuery(query=q, endpoint=ep_biotools))}")
remoteQuery(query=q, endpoint=ep_biotools)
# Out:
# Total number of bio.tools entries used to annotate EDAM data: 1
#   count
# 0  3284

# %% [markdown]
# ## Which EDAM data are used for bio.tools annotation?

# %%
q= """
PREFIX edam:<http://edamontology.org/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>

PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX bsc: <http://bioschemas.org/>
PREFIX bsct: <http://bioschemas.org/types/>

PREFIX sc: <http://schema.org/>
SELECT DISTINCT ?data WHERE {
    {
# ?biotools_id rdf:type <http://schema.org/SoftwareApplication> ;
   bsc:input [sc:additionalType ?data].        
    } UNION {
# ?biotools_id rdf:type <http://schema.org/SoftwareApplication> ;
   bsc:output [sc:additionalType ?data].        
    }
}

ORDER BY ASC(?data)
"""
print(f"EDAM data used to annotate bio.tools:")
remoteQuery(query=q, endpoint=ep_biotools)
# Out:
# EDAM data used to annotate bio.tools:
#                                   data
# 0    http://edamontology.org/data_0006
# 1    http://edamontology.org/data_0581
# 2    http://edamontology.org/data_0582
# 3    http://edamontology.org/data_0842
# 4    http://edamontology.org/data_0844
# 5    http://edamontology.org/data_0846
# 6    http://edamontology.org/data_0848
# 7    http://edamontology.org/data_0849
# 8    http://edamontology.org/data_0850
# 9    http://edamontology.org/data_0857
# 10   http://edamontology.org/data_0858
# 11   http://edamontology.org/data_0860
# 12   http://edamontology.org/data_0862
# 13   http://edamontology.org/data_0863
# 14   http://edamontology.org/data_0865
# 15   http://edamontology.org/data_0867
# 16   http://edamontology.org/data_0868
# 17   http://edamontology.org/data_0869
# 18   http://edamontology.org/data_0870
# 19   http://edamontology.org/data_0872
# 20   http://edamontology.org/data_0874
# 21   http://edamontology.org/data_0880
# 22   http://edamontology.org/data_0881
# 23   http://edamontology.org/data_0883
# 24   http://edamontology.org/data_0886
# 25   http://edamontology.org/data_0888
# 26   http://edamontology.org/data_0889
# 27   http://edamontology.org/data_0890
# 28   http://edamontology.org/data_0893
# 29   http://edamontology.org/data_0896
# 30   http://edamontology.org/data_0897
# 31   http://edamontology.org/data_0905
# 32   http://edamontology.org/data_0906
# 33   http://edamontology.org/data_0907
# 34   http://edamontology.org/data_0912
# 35   http://edamontology.org/data_0914
# 36   http://edamontology.org/data_0916
# 37   http://edamontology.org/data_0919
# 38   http://edamontology.org/data_0920
# 39   http://edamontology.org/data_0924
# 40   http://edamontology.org/data_0925
# 41   http://edamontology.org/data_0928
# 42   http://edamontology.org/data_0937
# 43   http://edamontology.org/data_0938
# 44   http://edamontology.org/data_0940
# 45   http://edamontology.org/data_0942
# 46   http://edamontology.org/data_0943
# 47   http://edamontology.org/data_0944
# 48   http://edamontology.org/data_0945
# 49   http://edamontology.org/data_0949
# 50   http://edamontology.org/data_0950
# 51   http://edamontology.org/data_0951
# 52   http://edamontology.org/data_0953
# 53   http://edamontology.org/data_0954
# 54   http://edamontology.org/data_0955
# 55   http://edamontology.org/data_0957
# 56   http://edamontology.org/data_0958
# 57   http://edamontology.org/data_0960
# 58   http://edamontology.org/data_0962
# 59   http://edamontology.org/data_0963
# 60   http://edamontology.org/data_0966
# 61   http://edamontology.org/data_0967
# 62   http://edamontology.org/data_0968
# 63   http://edamontology.org/data_0970
# 64   http://edamontology.org/data_0971
# 65   http://edamontology.org/data_0972
# 66   http://edamontology.org/data_0976
# 67   http://edamontology.org/data_0977
# 68   http://edamontology.org/data_0982
# 69   http://edamontology.org/data_0984
# 70   http://edamontology.org/data_0987
# 71   http://edamontology.org/data_0989
# 72   http://edamontology.org/data_0990
# 73   http://edamontology.org/data_0993
# 74   http://edamontology.org/data_1001
# 75   http://edamontology.org/data_1005
# 76   http://edamontology.org/data_1008
# 77   http://edamontology.org/data_1009
# 78   http://edamontology.org/data_1011
# 79   http://edamontology.org/data_1012
# 80   http://edamontology.org/data_1016
# 81   http://edamontology.org/data_1017
# 82   http://edamontology.org/data_1022
# 83   http://edamontology.org/data_1025
# 84   http://edamontology.org/data_1026
# 85   http://edamontology.org/data_1027
# 86   http://edamontology.org/data_1033
# 87   http://edamontology.org/data_1039
# 88   http://edamontology.org/data_1040
# 89   http://edamontology.org/data_1042
# 90   http://edamontology.org/data_1045
# 91   http://edamontology.org/data_1046
# 92   http://edamontology.org/data_1047
# 93   http://edamontology.org/data_1048
# 94   http://edamontology.org/data_1050
# 95   http://edamontology.org/data_1051
# 96   http://edamontology.org/data_1052
# 97   http://edamontology.org/data_1056
# 98   http://edamontology.org/data_1057
# 99   http://edamontology.org/data_1063
# 100  http://edamontology.org/data_1070
# 101  http://edamontology.org/data_1075
# 102  http://edamontology.org/data_1077
# 103  http://edamontology.org/data_1081
# 104  http://edamontology.org/data_1082
# 105  http://edamontology.org/data_1084
# 106  http://edamontology.org/data_1086
# 107  http://edamontology.org/data_1087
# 108  http://edamontology.org/data_1088
# 109  http://edamontology.org/data_1089
# 110  http://edamontology.org/data_1093
# 111  http://edamontology.org/data_1096
# 112  http://edamontology.org/data_1097
# 113  http://edamontology.org/data_1098
# 114  http://edamontology.org/data_1103
# 115  http://edamontology.org/data_1104
# 116  http://edamontology.org/data_1105
# 117  http://edamontology.org/data_1106
# 118  http://edamontology.org/data_1114
# 119  http://edamontology.org/data_1119
# 120  http://edamontology.org/data_1127
# 121  http://edamontology.org/data_1131
# 122  http://edamontology.org/data_1133
# 123  http://edamontology.org/data_1136
# 124  http://edamontology.org/data_1137
# 125  http://edamontology.org/data_1138
# 126  http://edamontology.org/data_1139
# 127  http://edamontology.org/data_1141
# 128  http://edamontology.org/data_1142
# 129  http://edamontology.org/data_1145
# 130  http://edamontology.org/data_1146
# 131  http://edamontology.org/data_1147
# 132  http://edamontology.org/data_1149
# 133  http://edamontology.org/data_1150
# 134  http://edamontology.org/data_1153
# 135  http://edamontology.org/data_1154
# 136  http://edamontology.org/data_1155
# 137  http://edamontology.org/data_1173
# 138  http://edamontology.org/data_1174
# 139  http://edamontology.org/data_1176
# 140  http://edamontology.org/data_1177
# 141  http://edamontology.org/data_1179
# 142  http://edamontology.org/data_1187
# 143  http://edamontology.org/data_1188
# 144  http://edamontology.org/data_1192
# 145  http://edamontology.org/data_1193
# 146  http://edamontology.org/data_1233
# 147  http://edamontology.org/data_1234
# 148  http://edamontology.org/data_1235
# 149  http://edamontology.org/data_1238
# 150  http://edamontology.org/data_1240
# 151  http://edamontology.org/data_1245
# 152  http://edamontology.org/data_1246
# 153  http://edamontology.org/data_1249
# 154  http://edamontology.org/data_1254
# 155  http://edamontology.org/data_1255
# 156  http://edamontology.org/data_1261
# 157  http://edamontology.org/data_1262
# 158  http://edamontology.org/data_1270
# 159  http://edamontology.org/data_1274
# 160  http://edamontology.org/data_1276
# 161  http://edamontology.org/data_1277
# 162  http://edamontology.org/data_1278
# 163  http://edamontology.org/data_1279
# 164  http://edamontology.org/data_1283
# 165  http://edamontology.org/data_1286
# 166  http://edamontology.org/data_1288
# 167  http://edamontology.org/data_1289
# 168  http://edamontology.org/data_1347
# 169  http://edamontology.org/data_1352
# 170  http://edamontology.org/data_1353
# 171  http://edamontology.org/data_1354
# 172  http://edamontology.org/data_1355
# 173  http://edamontology.org/data_1361
# 174  http://edamontology.org/data_1362
# 175  http://edamontology.org/data_1364
# 176  http://edamontology.org/data_1365
# 177  http://edamontology.org/data_1381
# 178  http://edamontology.org/data_1383
# 179  http://edamontology.org/data_1384
# 180  http://edamontology.org/data_1385
# 181  http://edamontology.org/data_1394
# 182  http://edamontology.org/data_1401
# 183  http://edamontology.org/data_1413
# 184  http://edamontology.org/data_1427
# 185  http://edamontology.org/data_1442
# 186  http://edamontology.org/data_1448
# 187  http://edamontology.org/data_1449
# 188  http://edamontology.org/data_1459
# 189  http://edamontology.org/data_1460
# 190  http://edamontology.org/data_1461
# 191  http://edamontology.org/data_1463
# 192  http://edamontology.org/data_1464
# 193  http://edamontology.org/data_1465
# 194  http://edamontology.org/data_1467
# 195  http://edamontology.org/data_1470
# 196  http://edamontology.org/data_1481
# 197  http://edamontology.org/data_1497
# 198  http://edamontology.org/data_1498
# 199  http://edamontology.org/data_1501
# 200  http://edamontology.org/data_1502
# 201  http://edamontology.org/data_1505
# 202  http://edamontology.org/data_1506
# 203  http://edamontology.org/data_1507
# 204  http://edamontology.org/data_1519
# 205  http://edamontology.org/data_1520
# 206  http://edamontology.org/data_1522
# 207  http://edamontology.org/data_1523
# 208  http://edamontology.org/data_1524
# 209  http://edamontology.org/data_1528
# 210  http://edamontology.org/data_1534
# 211  http://edamontology.org/data_1537
# 212  http://edamontology.org/data_1539
# 213  http://edamontology.org/data_1544
# 214  http://edamontology.org/data_1546
# 215  http://edamontology.org/data_1547
# 216  http://edamontology.org/data_1566
# 217  http://edamontology.org/data_1583
# 218  http://edamontology.org/data_1584
# 219  http://edamontology.org/data_1588
# 220  http://edamontology.org/data_1589
# 221  http://edamontology.org/data_1590
# 222  http://edamontology.org/data_1597
# 223  http://edamontology.org/data_1600
# 224  http://edamontology.org/data_1602
# 225  http://edamontology.org/data_1621
# 226  http://edamontology.org/data_1622
# 227  http://edamontology.org/data_1636
# 228  http://edamontology.org/data_1667
# 229  http://edamontology.org/data_1668
# 230  http://edamontology.org/data_1669
# 231  http://edamontology.org/data_1674
# 232  http://edamontology.org/data_1691
# 233  http://edamontology.org/data_1696
# 234  http://edamontology.org/data_1707
# 235  http://edamontology.org/data_1708
# 236  http://edamontology.org/data_1709
# 237  http://edamontology.org/data_1710
# 238  http://edamontology.org/data_1711
# 239  http://edamontology.org/data_1712
# 240  http://edamontology.org/data_1713
# 241  http://edamontology.org/data_1714
# 242  http://edamontology.org/data_1731
# 243  http://edamontology.org/data_1742
# 244  http://edamontology.org/data_1743
# 245  http://edamontology.org/data_1755
# 246  http://edamontology.org/data_1756
# 247  http://edamontology.org/data_1759
# 248  http://edamontology.org/data_1772
# 249  http://edamontology.org/data_1795
# 250  http://edamontology.org/data_1796
# 251  http://edamontology.org/data_1807
# 252  http://edamontology.org/data_1857
# 253  http://edamontology.org/data_1860
# 254  http://edamontology.org/data_1863
# 255  http://edamontology.org/data_1864
# 256  http://edamontology.org/data_1868
# 257  http://edamontology.org/data_1869
# 258  http://edamontology.org/data_1870
# 259  http://edamontology.org/data_1872
# 260  http://edamontology.org/data_1893
# 261  http://edamontology.org/data_1895
# 262  http://edamontology.org/data_1900
# 263  http://edamontology.org/data_1904
# 264  http://edamontology.org/data_1916
# 265  http://edamontology.org/data_1917
# 266  http://edamontology.org/data_2007
# 267  http://edamontology.org/data_2012
# 268  http://edamontology.org/data_2016
# 269  http://edamontology.org/data_2019
# 270  http://edamontology.org/data_2024
# 271  http://edamontology.org/data_2025
# 272  http://edamontology.org/data_2026
# 273  http://edamontology.org/data_2042
# 274  http://edamontology.org/data_2044
# 275  http://edamontology.org/data_2048
# 276  http://edamontology.org/data_2050
# 277  http://edamontology.org/data_2070
# 278  http://edamontology.org/data_2071
# 279  http://edamontology.org/data_2080
# 280  http://edamontology.org/data_2082
# 281  http://edamontology.org/data_2084
# 282  http://edamontology.org/data_2085
# 283  http://edamontology.org/data_2086
# 284  http://edamontology.org/data_2087
# 285  http://edamontology.org/data_2091
# 286  http://edamontology.org/data_2093
# 287  http://edamontology.org/data_2099
# 288  http://edamontology.org/data_2108
# 289  http://edamontology.org/data_2109
# 290  http://edamontology.org/data_2118
# 291  http://edamontology.org/data_2127
# 292  http://edamontology.org/data_2129
# 293  http://edamontology.org/data_2140
# 294  http://edamontology.org/data_2160
# 295  http://edamontology.org/data_2161
# 296  http://edamontology.org/data_2162
# 297  http://edamontology.org/data_2163
# 298  http://edamontology.org/data_2165
# 299  http://edamontology.org/data_2166
# 300  http://edamontology.org/data_2167
# 301  http://edamontology.org/data_2168
# 302  http://edamontology.org/data_2190
# 303  http://edamontology.org/data_2193
# 304  http://edamontology.org/data_2209
# 305  http://edamontology.org/data_2223
# 306  http://edamontology.org/data_2254
# 307  http://edamontology.org/data_2291
# 308  http://edamontology.org/data_2292
# 309  http://edamontology.org/data_2294
# 310  http://edamontology.org/data_2295
# 311  http://edamontology.org/data_2298
# 312  http://edamontology.org/data_2299
# 313  http://edamontology.org/data_2301
# 314  http://edamontology.org/data_2302
# 315  http://edamontology.org/data_2309
# 316  http://edamontology.org/data_2313
# 317  http://edamontology.org/data_2314
# 318  http://edamontology.org/data_2316
# 319  http://edamontology.org/data_2317
# 320  http://edamontology.org/data_2318
# 321  http://edamontology.org/data_2319
# 322  http://edamontology.org/data_2320
# 323  http://edamontology.org/data_2327
# 324  http://edamontology.org/data_2337
# 325  http://edamontology.org/data_2338
# 326  http://edamontology.org/data_2339
# 327  http://edamontology.org/data_2342
# 328  http://edamontology.org/data_2343
# 329  http://edamontology.org/data_2344
# 330  http://edamontology.org/data_2345
# 331  http://edamontology.org/data_2347
# 332  http://edamontology.org/data_2348
# 333  http://edamontology.org/data_2349
# 334  http://edamontology.org/data_2353
# 335  http://edamontology.org/data_2354
# 336  http://edamontology.org/data_2355
# 337  http://edamontology.org/data_2365
# 338  http://edamontology.org/data_2367
# 339  http://edamontology.org/data_2368
# 340  http://edamontology.org/data_2369
# 341  http://edamontology.org/data_2370
# 342  http://edamontology.org/data_2371
# 343  http://edamontology.org/data_2373
# 344  http://edamontology.org/data_2374
# 345  http://edamontology.org/data_2380
# 346  http://edamontology.org/data_2383
# 347  http://edamontology.org/data_2384
# 348  http://edamontology.org/data_2385
# 349  http://edamontology.org/data_2388
# 350  http://edamontology.org/data_2389
# 351  http://edamontology.org/data_2390
# 352  http://edamontology.org/data_2392
# 353  http://edamontology.org/data_2393
# 354  http://edamontology.org/data_2398
# 355  http://edamontology.org/data_2523
# 356  http://edamontology.org/data_2526
# 357  http://edamontology.org/data_2530
# 358  http://edamontology.org/data_2531
# 359  http://edamontology.org/data_2534
# 360  http://edamontology.org/data_2535
# 361  http://edamontology.org/data_2536
# 362  http://edamontology.org/data_2537
# 363  http://edamontology.org/data_2538
# 364  http://edamontology.org/data_2563
# 365  http://edamontology.org/data_2580
# 366  http://edamontology.org/data_2583
# 367  http://edamontology.org/data_2589
# 368  http://edamontology.org/data_2594
# 369  http://edamontology.org/data_2597
# 370  http://edamontology.org/data_2600
# 371  http://edamontology.org/data_2603
# 372  http://edamontology.org/data_2610
# 373  http://edamontology.org/data_2618
# 374  http://edamontology.org/data_2619
# 375  http://edamontology.org/data_2622
# 376  http://edamontology.org/data_2628
# 377  http://edamontology.org/data_2639
# 378  http://edamontology.org/data_2646
# 379  http://edamontology.org/data_2648
# 380  http://edamontology.org/data_2649
# 381  http://edamontology.org/data_2654
# 382  http://edamontology.org/data_2655
# 383  http://edamontology.org/data_2666
# 384  http://edamontology.org/data_2700
# 385  http://edamontology.org/data_2701
# 386  http://edamontology.org/data_2702
# 387  http://edamontology.org/data_2704
# 388  http://edamontology.org/data_2709
# 389  http://edamontology.org/data_2710
# 390  http://edamontology.org/data_2711
# 391  http://edamontology.org/data_2713
# 392  http://edamontology.org/data_2714
# 393  http://edamontology.org/data_2715
# 394  http://edamontology.org/data_2716
# 395  http://edamontology.org/data_2717
# 396  http://edamontology.org/data_2719
# 397  http://edamontology.org/data_2720
# 398  http://edamontology.org/data_2721
# 399  http://edamontology.org/data_2723
# 400  http://edamontology.org/data_2725
# 401  http://edamontology.org/data_2729
# 402  http://edamontology.org/data_2730
# 403  http://edamontology.org/data_2731
# 404  http://edamontology.org/data_2732
# 405  http://edamontology.org/data_2737
# 406  http://edamontology.org/data_2739
# 407  http://edamontology.org/data_2741
# 408  http://edamontology.org/data_2744
# 409  http://edamontology.org/data_2746
# 410  http://edamontology.org/data_2749
# 411  http://edamontology.org/data_2751
# 412  http://edamontology.org/data_2752
# 413  http://edamontology.org/data_2753
# 414  http://edamontology.org/data_2755
# 415  http://edamontology.org/data_2756
# 416  http://edamontology.org/data_2757
# 417  http://edamontology.org/data_2758
# 418  http://edamontology.org/data_2759
# 419  http://edamontology.org/data_2762
# 420  http://edamontology.org/data_2764
# 421  http://edamontology.org/data_2769
# 422  http://edamontology.org/data_2770
# 423  http://edamontology.org/data_2771
# 424  http://edamontology.org/data_2772
# 425  http://edamontology.org/data_2775
# 426  http://edamontology.org/data_2776
# 427  http://edamontology.org/data_2777
# 428  http://edamontology.org/data_2778
# 429  http://edamontology.org/data_2782
# 430  http://edamontology.org/data_2784
# 431  http://edamontology.org/data_2787
# 432  http://edamontology.org/data_2789
# 433  http://edamontology.org/data_2791
# 434  http://edamontology.org/data_2792
# 435  http://edamontology.org/data_2793
# 436  http://edamontology.org/data_2794
# 437  http://edamontology.org/data_2795
# 438  http://edamontology.org/data_2796
# 439  http://edamontology.org/data_2797
# 440  http://edamontology.org/data_2798
# 441  http://edamontology.org/data_2799
# 442  http://edamontology.org/data_2800
# 443  http://edamontology.org/data_2802
# 444  http://edamontology.org/data_2803
# 445  http://edamontology.org/data_2804
# 446  http://edamontology.org/data_2805
# 447  http://edamontology.org/data_2812
# 448  http://edamontology.org/data_2835
# 449  http://edamontology.org/data_2836
# 450  http://edamontology.org/data_2850
# 451  http://edamontology.org/data_2851
# 452  http://edamontology.org/data_2854
# 453  http://edamontology.org/data_2855
# 454  http://edamontology.org/data_2856
# 455  http://edamontology.org/data_2858
# 456  http://edamontology.org/data_2865
# 457  http://edamontology.org/data_2872
# 458  http://edamontology.org/data_2877
# 459  http://edamontology.org/data_2878
# 460  http://edamontology.org/data_2884
# 461  http://edamontology.org/data_2886
# 462  http://edamontology.org/data_2887
# 463  http://edamontology.org/data_2892
# 464  http://edamontology.org/data_2899
# 465  http://edamontology.org/data_2905
# 466  http://edamontology.org/data_2906
# 467  http://edamontology.org/data_2907
# 468  http://edamontology.org/data_2909
# 469  http://edamontology.org/data_2912
# 470  http://edamontology.org/data_2914
# 471  http://edamontology.org/data_2955
# 472  http://edamontology.org/data_2958
# 473  http://edamontology.org/data_2959
# 474  http://edamontology.org/data_2968
# 475  http://edamontology.org/data_2969
# 476  http://edamontology.org/data_2970
# 477  http://edamontology.org/data_2974
# 478  http://edamontology.org/data_2975
# 479  http://edamontology.org/data_2976
# 480  http://edamontology.org/data_2977
# 481  http://edamontology.org/data_2978
# 482  http://edamontology.org/data_2979
# 483  http://edamontology.org/data_2984
# 484  http://edamontology.org/data_2992
# 485  http://edamontology.org/data_3002
# 486  http://edamontology.org/data_3021
# 487  http://edamontology.org/data_3028
# 488  http://edamontology.org/data_3108
# 489  http://edamontology.org/data_3110
# 490  http://edamontology.org/data_3111
# 491  http://edamontology.org/data_3112
# 492  http://edamontology.org/data_3113
# 493  http://edamontology.org/data_3115
# 494  http://edamontology.org/data_3117
# 495  http://edamontology.org/data_3128
# 496  http://edamontology.org/data_3134
# 497  http://edamontology.org/data_3148
# 498  http://edamontology.org/data_3154
# 499  http://edamontology.org/data_3181
# 500  http://edamontology.org/data_3210
# 501  http://edamontology.org/data_3236
# 502  http://edamontology.org/data_3241
# 503  http://edamontology.org/data_3264
# 504  http://edamontology.org/data_3271
# 505  http://edamontology.org/data_3272
# 506  http://edamontology.org/data_3273
# 507  http://edamontology.org/data_3274
# 508  http://edamontology.org/data_3275
# 509  http://edamontology.org/data_3424
# 510  http://edamontology.org/data_3425
# 511  http://edamontology.org/data_3442
# 512  http://edamontology.org/data_3449
# 513  http://edamontology.org/data_3479
# 514  http://edamontology.org/data_3483
# 515  http://edamontology.org/data_3488
# 516  http://edamontology.org/data_3490
# 517  http://edamontology.org/data_3492
# 518  http://edamontology.org/data_3494
# 519  http://edamontology.org/data_3495
# 520  http://edamontology.org/data_3496
# 521  http://edamontology.org/data_3497
# 522  http://edamontology.org/data_3498
# 523  http://edamontology.org/data_3505
# 524  http://edamontology.org/data_3509
# 525  http://edamontology.org/data_3546
# 526  http://edamontology.org/data_3558
# 527  http://edamontology.org/data_3567
# 528  http://edamontology.org/data_3568
# 529  http://edamontology.org/data_3667
# 530  http://edamontology.org/data_3668
# 531  http://edamontology.org/data_3669
# 532  http://edamontology.org/data_3671
# 533  http://edamontology.org/data_3707
# 534  http://edamontology.org/data_3718
# 535  http://edamontology.org/data_3719
# 536  http://edamontology.org/data_3720
# 537  http://edamontology.org/data_3721
# 538  http://edamontology.org/data_3722
# 539  http://edamontology.org/data_3723
# 540  http://edamontology.org/data_3736
# 541  http://edamontology.org/data_3753
# 542  http://edamontology.org/data_3754
# 543  http://edamontology.org/data_3756
# 544  http://edamontology.org/data_3768
# 545  http://edamontology.org/data_3779
# 546  http://edamontology.org/data_3786
# 547  http://edamontology.org/data_3806
# 548  http://edamontology.org/data_3808
# 549  http://edamontology.org/data_3842
# 550  http://edamontology.org/data_3861
# 551  http://edamontology.org/data_3869
# 552  http://edamontology.org/data_3870
# 553  http://edamontology.org/data_3871
# 554  http://edamontology.org/data_3872
# 555  http://edamontology.org/data_3905
# 556  http://edamontology.org/data_3914
# 557  http://edamontology.org/data_3917
# 558  http://edamontology.org/data_3932
